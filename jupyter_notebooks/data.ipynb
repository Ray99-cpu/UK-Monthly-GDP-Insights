# %%
import pandas as pd
import numpy as np
! pip install matplotlib

df = pd.read_csv("../jupyter_notebooks/data/raw_data/gdp_data.csv")
print(df.head())
# Out:
# ...
#   Using cached matplotlib-3.10.3-cp312-cp312-win_amd64.whl.metadata (11 kB)
# ...
#   Using cached contourpy-1.3.2-cp312-cp312-win_amd64.whl.metadata (5.5 kB)
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached fonttools-4.58.4-cp312-cp312-win_amd64.whl.metadata (108 kB)
# ...
#   Using cached kiwisolver-1.4.8-cp312-cp312-win_amd64.whl.metadata (6.3 kB)
# ...
#   Using cached pillow-11.2.1-cp312-cp312-win_amd64.whl.metadata (9.1 kB)
# ...
#   Using cached pyparsing-3.2.3-py3-none-any.whl.metadata (5.0 kB)
# ...
# Using cached matplotlib-3.10.3-cp312-cp312-win_amd64.whl (8.1 MB)
# Using cached contourpy-1.3.2-cp312-cp312-win_amd64.whl (223 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Using cached fonttools-4.58.4-cp312-cp312-win_amd64.whl (2.2 MB)
# Using cached kiwisolver-1.4.8-cp312-cp312-win_amd64.whl (71 kB)
# Using cached pillow-11.2.1-cp312-cp312-win_amd64.whl (2.7 MB)
# Using cached pyparsing-3.2.3-py3-none-any.whl (111 kB)
# ...
#
# ...

# %%
new_df = df.dropna()
print(new_df.head())
# Out:
#            Title Gross Value Added - Monthly (Index 1dp) :CVM SA  \
# 0           CDID                                            ECY2
# 3   Release Date                                      12-06-2025
# 4   Next release                                    11 July 2025
# 20      1998 MAR                                            64.9
# 21      1998 APR                                            65.5
#
#    Agriculture, Forestry and Fishing (Index 1dp) :CVM SA  \
# 0                                                ECY3
# 3                                          12-06-2025
# 4                                        11 July 2025
# 20                                               62.2
# 21                                               62.8
#
#    Production Industries - Total (Index 1dp) :CVM SA  \
# 0                                               ECY4
# 3                                         12-06-2025
# 4                                       11 July 2025
# ...

# %%
new_df.to_csv("../jupyter_notebooks/data/clean_data/gdp_data_cleaned.csv")

# %%
new_df.isnull().sum()
# Out:
# Title                                                                                                      0
# Gross Value Added - Monthly (Index 1dp) :CVM SA                                                            0
# Agriculture, Forestry and Fishing (Index 1dp) :CVM SA                                                      0
# Production Industries - Total (Index 1dp) :CVM SA                                                          0
# Mining and Quarrying (Index 1dp) :CVM SA                                                                   0
#                                                                                                           ..
# Education (3m on 3m 1 year ago contribution) :CVM SA                                                       0
# Human health and social work activities (3m on 3m 1 year ago contribution) :CVM SA                         0
# Arts, Entertainment and Recreation (3m on 3m 1 year ago contribution) :CVM SA                              0
# ...

# %%
print(new_df.head())
# Out:
#            Title Gross Value Added - Monthly (Index 1dp) :CVM SA  \
# 0           CDID                                            ECY2
# 3   Release Date                                      12-06-2025
# 4   Next release                                    11 July 2025
# 20      1998 MAR                                            64.9
# 21      1998 APR                                            65.5
#
#    Agriculture, Forestry and Fishing (Index 1dp) :CVM SA  \
# 0                                                ECY3
# 3                                          12-06-2025
# 4                                        11 July 2025
# 20                                               62.2
# 21                                               62.8
#
#    Production Industries - Total (Index 1dp) :CVM SA  \
# 0                                               ECY4
# 3                                         12-06-2025
# 4                                       11 July 2025
# ...

# %%
numeric_cols = new_df.select_dtypes(include='number').columns
value = new_df.groupby("Gross Value Added - Monthly (Index 1dp) :CVM SA")[numeric_cols].mean()
value.plot(kind="hist",  title="Average Monthly Gross Value Added (CVM SA) by Year",ylabel="Average Monthly Gross Value Added ")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[33], line 3
#       1 numeric_cols = new_df.select_dtypes(include='number').columns
#       2 value = new_df.groupby("Gross Value Added - Monthly (Index 1dp) :CVM SA")[numeric_cols].mean()
# ----> 3 value.plot(kind="hist",  title="Average Monthly Gross Value Added (CVM SA) by Year",ylabel="Average Monthly Gross Value Added ")
#
# File c:\Users\rayaf\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\plotting\_core.py:947, in PlotAccessor.__call__(self, *args, **kwargs)
#     946 def __call__(self, *args, **kwargs):
# --> 947     plot_backend = _get_plot_backend(kwargs.pop("backend", None))
#     949     x, y, kind, kwargs = self._get_call_args(
#     950         plot_backend.__name__, self._parent, args, kwargs
#     951     )
#     953     kind = self._kind_aliases.get(kind, kind)
#
# ...
